# %% [markdown]
# # Data collection

# %% [markdown]
# ## Pipeline Overview:

# %% [markdown]
# **1. Data Collection** - Fetch player data from the **Lichess API**: usernames, game details, ratings, moves, and openings.
#
# **2. Data Processing** - Clean up the raw data: extract openings, check game outcomes, calculate rating differences, and handle missing info.
#
# **3. Data Export** - Save the cleaned data into a **CSV** for easy manipulation, analysis, and reporting.
#
# **4. Data Analysis** - Manipulate the data as necessary, building dataframes for different visualizations. Look at win rates: figure out which **openings** and **playstyles** work best for different colors at different ranks, check out how **rating gaps** affect match results, see which **colors** typically win more frequently, see how **move count** (game length) might be impacted by the details of a game.

# %% [markdown]
# ### Data Collection:

# %% [markdown]
# #### 0. Imports

# %%
# !nvidia-smi
# Out:
# Fri Oct 25 17:35:02 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# Install required libraries
# %pip install berserk pandas chess stockfish matplotlib seaborn
# Out:
# Requirement already satisfied: berserk in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: chess in /usr/local/lib/python3.10/dist-packages (1.11.1)
# Requirement already satisfied: stockfish in /usr/local/lib/python3.10/dist-packages (3.28.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: deprecated<2.0.0,>=1.2.14 in /usr/local/lib/python3.10/dist-packages (from berserk) (1.2.14)
# Requirement already satisfied: ndjson<0.4.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from berserk) (0.3.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from berserk) (2.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.28.2 in /usr/local/lib/python3.10/dist-packages (from berserk) (2.32.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.1 in /usr/local/lib/python3.10/dist-packages (from berserk) (4.12.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated<2.0.0,>=1.2.14->berserk) (1.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.8.2->berserk) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.28.2->berserk) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.28.2->berserk) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.28.2->berserk) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.28.2->berserk) (2024.8.30)

# %%
import berserk
import pandas as pd
import chess
import chess.polyglot
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import plotly.express as px
token = ""
session = berserk.TokenSession(token)
client = berserk.Client(session=session)
warnings.filterwarnings('ignore')

# %%
# ---------------------------
# Step 1: Set Token
# ---------------------------

token = ""  # lichess token  e.g. or .env works. 

if not token:
    raise ValueError("No token.")

# %% [markdown]
# #### 2. Query generation API Code

# %%
# ---------------------------
# Step 2: Init Client
# ---------------------------

session = berserk.TokenSession(token)
client = berserk.Client(session=session)

# %%
# ---------------------------
# Step 3: Fetch Players
# ---------------------------

def get_top_players(perf='blitz', cnt=100):
    try:
        lb = client.users.get_leaderboard(perf_type=perf, count=cnt)  # leaderboard
        return [user['username'] for user in lb]  # names
    except berserk.exceptions.ResponseError as e:
        print(f"Error: {e}")
        return []  # return empty if error

# perf types to fetch
perf_types = {'blitz': 200, 'bullet': 200, 'rapid': 200, 'classical': 200}

# collect all usernames
all_users = set()
for perf, cnt in perf_types.items():
    users = get_top_players(perf, cnt)
    all_users.update(users)
    print(f"Fetched {len(users)} {perf}")

print(f"Total: {len(all_users)} users")
# Out:
# Fetched 200 blitz
# Fetched 200 bullet
# Fetched 200 rapid
# Fetched 200 classical
# Total: 752 users

# %%
# ---------------------------
# Step 4: Helper Functions
# ---------------------------

# retry fetching games
def get_games(username, max_games, retries=3, delay=5):
    for attempt in range(retries):
        try:
            games = client.games.export_by_player(
                username,
                max=max_games,
                perf_type='classical',  # Ensure 'classical' is correctly specified
                moves=True,
                pgn_in_json=False,
                clocks=False,
                evals=False,
                opening=True,
                as_pgn=False
            )
            return list(games)  # success
        except berserk.exceptions.ResponseError as e:
            if e.status_code == 429:  # limit hit
                print(f"Wait {delay} sec...")
                time.sleep(delay)
            else:
                print(f"Error: {e}. Retry {attempt + 1}")
                time.sleep(delay)
        except Exception as e:
            print(f"Error: {e}. Retry {attempt + 1}")
            time.sleep(delay)
    return []  # fail

# determine opening
def get_opening(moves):
    board = chess.Board()
    opening_name = 'Unknown'
    eco_code = 'Unknown'

    for move_uci in moves.split()[:20]:  # Limit to first 20 moves
        try:
            move = chess.Move.from_uci(move_uci)
            if move not in board.legal_moves:
                break  # Illegal move
            board.push(move)
            #Using python-chess's eco database to get the opening names
            current_opening = chess.polyglot.opening_name(board)
            if current_opening != "Unknown Opening":
                opening_name = current_opening
                eco_code = 'N/A'  # if unknown we cant use eco
                break
        except Exception as e:
            print(f"Error parsing move {move_uci}: {e}")
            break  # Invalid move

    opening = f"{eco_code}: {opening_name}"
    return opening

# %%
# ---------------------------
# Step 5: Fetch & Process Games
# ---------------------------

max_games = 10000
sleep_time = 1  # seconds to wait

all_data = []  # store game data
print("Fetching games...")

for idx, user in enumerate(all_users):
    print(f"User {idx + 1}: {user}")
    games = get_games(user, max_games)
    print(f"Got {len(games)} games.")

    for game in games:
        try:
            white = game['players']['white'].get('user', {}).get('name', 'Anon')
            white_rating = game['players']['white'].get('rating')
            black = game['players']['black'].get('user', {}).get('name', 'Anon')
            black_rating = game['players']['black'].get('rating')

            game_id = game['id']
            link = f"https://lichess.org/{game_id}"

            opening = game.get('opening', {}).get('name', 'Unknown')
            moves = game.get('moves', '')
            if opening == 'Unknown':
                opening = get_opening(moves)

            winner = game.get('winner', 'draw')
            move_count = len(moves.split())

            all_data.append({
                'game_id': game_id,
                'white': white,
                'white_rating': white_rating,
                'black': black,
                'black_rating': black_rating,
                'opening': opening,
                'winner': winner,
                'moves': move_count,
                'link': link
            })
        except Exception as e:
            print(f"Error in {game.get('id', 'Unknown')}: {e}")

    time.sleep(sleep_time)  # respect limits

print(f"Total games: {len(all_data)}")
# Out:
# Fetching games...
# User 1: zwenna
# Got 156 games.
# User 2: Erebuni91
# Got 1 games.
# User 3: qwl8
# Got 85 games.
# User 4: Mishka_The_Great
# Got 2 games.
# User 5: Zombieblitz
# Got 45 games.
# User 6: SanthoshAyyappan
# Got 397 games.
# User 7: Nikolayi10
# Got 544 games.
# User 8: joddle
# Got 0 games.
# User 9: NeSuBaMu
# Got 317 games.
# User 10: gmluke
# Got 0 games.
# User 11: Tyoma888
# Got 16 games.
# User 12: Wu_Kong
# Got 4 games.
# User 13: abudabi22840
# Got 0 games.
# User 14: chuckbranson
# Got 3330 games.
# User 15: Superferz7
# Got 0 games.
# User 16: CryptoPanda
# Got 442 games.
# User 17: igormezentsev
# Got 786 games.
# Error parsing move e4: expected uci string to be of length 4 or 5: 'e4'
# User 18: zweidreizehen
# Got 0 games.
# User 19: AlvaroVargasD
# Got 1158 games.
# User 20: defenestration30
# Got 147 games.
# User 21: apollothedog
# Got 0 games.
# User 22: chessed70
# Got 11 games.
# User 23: terrapin
# Got 1273 games.
# User 24: KR228
# Got 20 games.
# User 25: Andrey_Esipenko
# Got 0 games.
# User 26: jambocomeon
# Got 471 games.
# Error parsing move Be7: expected uci string to be of length 4 or 5: 'Be7'
# User 27: UtemisovDamir
# Got 35 games.
# User 28: Jamigo123
# Got 2709 games.
# User 29: Mirakel05
# Got 29 games.
# Error parsing move Bd6: expected uci string to be of length 4 or 5: 'Bd6'
# Error parsing move f5: expected uci string to be of length 4 or 5: 'f5'
# Error parsing move f5: expected uci string to be of length 4 or 5: 'f5'
# Error parsing move f4: expected uci string to be of length 4 or 5: 'f4'
# Error parsing move Bc4: expected uci string to be of length 4 or 5: 'Bc4'
# Error parsing move Bb3: expected uci string to be of length 4 or 5: 'Bb3'
# Error parsing move c5: expected uci string to be of length 4 or 5: 'c5'
# Error parsing move Bb3: expected uci string to be of length 4 or 5: 'Bb3'
# Error parsing move O-O: expected uci string to be of length 4 or 5: 'O-O'
# Error parsing move d6: expected uci string to be of length 4 or 5: 'd6'
# Error parsing move c5: expected uci string to be of length 4 or 5: 'c5'
# Error parsing move Qe2: expected uci string to be of length 4 or 5: 'Qe2'
# Error parsing move O-O: expected uci string to be of length 4 or 5: 'O-O'
# Error parsing move Be2: expected uci string to be of length 4 or 5: 'Be2'
# Error parsing move Be2: expected uci string to be of length 4 or 5: 'Be2'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move dxc5: invalid uci: 'dxc5'
# Error parsing move Be2: expected uci string to be of length 4 or 5: 'Be2'
# Error parsing move Be2: expected uci string to be of length 4 or 5: 'Be2'
# Error parsing move Be2: expected uci string to be of length 4 or 5: 'Be2'
# Error parsing move Be2: expected uci string to be of length 4 or 5: 'Be2'
# User 30: TrainingAccount200
# Got 0 games.
# User 31: black_knight22
# Got 0 games.
# User 32: JoshuaKimmich22
# Got 0 games.
# User 33: Greensocks22
# Got 2 games.
# User 34: manchesterisred
# Got 26 games.
# User 35: kingrunner32
# Got 7 games.
# User 36: chess-art-us
# Got 2 games.
# User 37: SktFaker
# Got 4 games.
# User 38: ftorodent
# Got 17 games.
# User 39: varunvar
# Got 33 games.
# User 40: Chess_Computer_101
# Got 2 games.
# User 41: metan0ia
# Got 2 games.
# User 42: DeljemPivo
# Got 1 games.
# User 43: Forester_19
# Got 0 games.
# User 44: Chess_diviner
# Got 0 games.
# User 45: chesslh
# Got 0 games.
# User 46: Gromis12
# Got 0 games.
# User 47: AlexandrosMouzakidis
# Got 0 games.
# User 48: Bhavya33
# Got 945 games.
# User 49: Qudit
# Got 265 games.
# User 50: king6719
# Got 169 games.
# User 51: eskeropouloss
# Got 1 games.
# User 52: Prishtin
# Got 230 games.
# User 53: GGuseinov
# Got 60 games.
# User 54: yeyq
# Got 392 games.
# User 55: Emmanuel1233
# Got 0 games.
# User 56: Kholpilova
# Got 2689 games.
# User 57: vjcheslav
# Got 2577 games.
# User 58: nxduc
# Got 69 games.
# Error parsing move c5: expected uci string to be of length 4 or 5: 'c5'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# User 59: FANNY_SLI
# Got 0 games.
# User 60: Kawaciukov
# Got 265 games.
# User 61: SHERLOCKEDDDDD
# Got 0 games.
# User 62: Sanjeevi108
# Got 253 games.
# User 63: Kostik_Mostik
# Got 77 games.
# User 64: Akshak
# Got 412 games.
# User 65: Rise001
# Got 538 games.
# Error parsing move Rc8+: invalid uci: 'Rc8+'
# User 66: sapphire_phoenix
# Got 0 games.
# User 67: elephbush
# Got 872 games.
# User 68: ivan124
# Got 7 games.
# User 69: RookyMightyKnight
# Got 133 games.
# User 70: ChessClubKomotini
# Got 765 games.
# User 71: chessm1105
# Got 19 games.
# User 72: wateenellende
# Got 8 games.
# User 73: Tuzakli_Egitim
# Got 38 games.
# User 74: Salvatore911
# Got 0 games.
# User 75: pirata74
# Got 580 games.
# User 76: Just_No_Fun
# Got 7 games.
# Error parsing move Rf2: expected uci string to be of length 4 or 5: 'Rf2'
# Error parsing move Rf2: expected uci string to be of length 4 or 5: 'Rf2'
# Error parsing move a4: expected uci string to be of length 4 or 5: 'a4'
# Error parsing move d4: expected uci string to be of length 4 or 5: 'd4'
# Error parsing move d6: expected uci string to be of length 4 or 5: 'd6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# User 77: icheetbutproveit
# Got 521 games.
# User 78: dauANHbac
# Got 0 games.
# User 79: Nosporchess
# Got 306 games.
# User 80: DrMelekess
# Got 2 games.
# User 81: TheMagnet
# Got 0 games.
# User 82: snowbyy
# Got 0 games.
# User 83: Detective_08
# Got 1 games.
# User 84: RussianBlizzard
# Got 3 games.
# User 85: Paff-Morris
# Got 563 games.
# User 86: L04d1ng
# Got 36 games.
# User 87: Martin-Luthers-King
# Got 4606 games.
# User 88: BetterCollSoul
# Got 35 games.
# User 89: Morozevic2305
# Got 92 games.
# User 90: Alexis_Emil_Maribao
# Got 9 games.
# User 91: tommy_pug
# Got 77 games.
# User 92: CoachFede
# Got 17 games.
# User 93: Eldarchessplayer
# Got 99 games.
# User 94: Anuar_Is
# Got 0 games.
# User 95: LEV2310
# Got 303 games.
# Error parsing move Qa4: expected uci string to be of length 4 or 5: 'Qa4'
# User 96: kc6
# Got 1199 games.
# User 97: StochasticVolatility
# Got 13 games.
# User 98: EraserGodzilla
# Got 0 games.
# User 99: geneh59
# Got 2394 games.
# User 100: Dybamo
# Got 312 games.
# User 101: TheBullyBoy
# Got 0 games.
# User 102: nihalsarin2004
# Got 0 games.
# User 103: Esssquire
# Got 12 games.
# User 104: david7torres
# Got 80 games.
# User 105: kozuba
# Got 84 games.
# User 106: Elwe
# Got 408 games.
# User 107: sicilian3
# Got 160 games.
# Error parsing move e6: expected uci string to be of length 4 or 5: 'e6'
# Error parsing move Qb6: expected uci string to be of length 4 or 5: 'Qb6'
# Error parsing move e5: expected uci string to be of length 4 or 5: 'e5'
# Error parsing move Qb6: expected uci string to be of length 4 or 5: 'Qb6'
# Error parsing move Nc6: expected uci string to be of length 4 or 5: 'Nc6'
# Error parsing move Qd2: expected uci string to be of length 4 or 5: 'Qd2'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move Nc5: expected uci string to be of length 4 or 5: 'Nc5'
# Error parsing move c5: expected uci string to be of length 4 or 5: 'c5'
# Error parsing move Qb3: expected uci string to be of length 4 or 5: 'Qb3'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move Nxb4: invalid uci: 'Nxb4'
# Error parsing move d3: expected uci string to be of length 4 or 5: 'd3'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move Qd7: expected uci string to be of length 4 or 5: 'Qd7'
# Error parsing move b5: expected uci string to be of length 4 or 5: 'b5'
# Error parsing move b5: expected uci string to be of length 4 or 5: 'b5'
# Error parsing move Nb6: expected uci string to be of length 4 or 5: 'Nb6'
# Error parsing move Be7: expected uci string to be of length 4 or 5: 'Be7'
# Error parsing move c5: expected uci string to be of length 4 or 5: 'c5'
# Error parsing move c5: expected uci string to be of length 4 or 5: 'c5'
# Error parsing move Qd6: expected uci string to be of length 4 or 5: 'Qd6'
# Error parsing move c4: expected uci string to be of length 4 or 5: 'c4'
# Error parsing move Rb2: expected uci string to be of length 4 or 5: 'Rb2'
# Error parsing move Kf8: expected uci string to be of length 4 or 5: 'Kf8'
# Error parsing move e5: expected uci string to be of length 4 or 5: 'e5'
# Error parsing move axb5: invalid uci: 'axb5'
# Error parsing move axb5: invalid uci: 'axb5'
# Error parsing move axb5: invalid uci: 'axb5'
# Error parsing move bxc5: invalid uci: 'bxc5'
# Error parsing move O-O: expected uci string to be of length 4 or 5: 'O-O'
# Error parsing move f5: expected uci string to be of length 4 or 5: 'f5'
# Error parsing move Nxd3: invalid uci: 'Nxd3'
# Error parsing move Ba6: expected uci string to be of length 4 or 5: 'Ba6'
# Error parsing move d4: expected uci string to be of length 4 or 5: 'd4'
# Error parsing move b6: expected uci string to be of length 4 or 5: 'b6'
# Error parsing move e6: expected uci string to be of length 4 or 5: 'e6'
# Error parsing move e6: expected uci string to be of length 4 or 5: 'e6'
# Error parsing move e6: expected uci string to be of length 4 or 5: 'e6'
# Error parsing move e5: expected uci string to be of length 4 or 5: 'e5'
# Error parsing move O-O: expected uci string to be of length 4 or 5: 'O-O'
# Error parsing move Rg7: expected uci string to be of length 4 or 5: 'Rg7'
# Error parsing move Rag2: invalid uci: 'Rag2'
# Error parsing move Nc6: expected uci string to be of length 4 or 5: 'Nc6'
# User 108: minelollipop
# Got 39 games.
# User 109: Viktor_Tahirov555
# Got 2624 games.
# Error parsing move Qfxf7#: expected uci string to be of length 4 or 5: 'Qfxf7#'
# User 110: EtienneBacrot
# Got 0 games.
# User 111: peradetlic83
# Got 67 games.
# User 112: Punchen
# Got 2 games.
# User 113: jjosujjosu
# Got 0 games.
# User 114: SirLahmacun
# Got 0 games.
# User 115: ChesskingOriginal
# Got 1045 games.
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move Nc6: expected uci string to be of length 4 or 5: 'Nc6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# User 116: Yorkster
# Got 292 games.
# User 117: mithiLesH2012
# Got 266 games.
# User 118: ImagineKnight
# Got 3 games.
# User 119: justantan
# Got 39 games.
# User 120: GeNer4tion_KiLL
# Got 0 games.
# User 121: Leverkuhn
# Got 186 games.
# User 122: gennadigleizerov
# Got 0 games.
# User 123: sublimation1
# Got 0 games.
# User 124: AlexTriapishko
# Got 31 games.
# User 125: RedWarrior25
# Got 24 games.
# User 126: nepoloh686
# Got 0 games.
# User 127: freedomfighter1234
# Got 0 games.
# User 128: Pit_0_corto
# Got 98 games.
# User 129: TOMRATD
# Got 119 games.
# User 130: mrtvola
# Got 1583 games.
# User 131: caching
# Got 0 games.
# User 132: ARM__55555
# Got 742 games.
# User 133: Mainrival
# Got 193 games.
# User 134: CHESSMAESTR21
# Got 0 games.
# User 135: ChessStrawberry2020
# Got 106 games.
# User 136: DrAgnevstein
# Got 0 games.
# User 137: RoadToFM-L
# Got 9 games.
# User 138: EmperatorTrajano
# Got 0 games.
# User 139: AlexanderMitrofanov
# Got 832 games.
# User 140: Uralan77
# Got 3 games.
# User 141: Agagagag
# Got 0 games.
# User 142: Chewbacca18
# Got 45 games.
# User 143: Protagonist98
# Got 0 games.
# User 144: dr_rghtyv
# Got 0 games.
# User 145: JavierValeraEspejo
# Got 6 games.
# User 146: my_cupcake
# Got 34 games.
# User 147: Smoking_Samra
# Got 0 games.
# User 148: Chesscomispaytowin
# Got 0 games.
# User 149: bobrock2024
# Got 0 games.
# User 150: Koalanaattor
# Got 128 games.
# User 151: El_ninho9
# Got 0 games.
# User 152: razinioshaazuka
# Got 0 games.
# User 153: iamstraw
# Got 46 games.
# User 154: miwi2
# Got 594 games.
# User 155: Kurald_Galain
# Got 0 games.
# User 156: Dynamirock
# Got 0 games.
# User 157: misterbluff
# Got 0 games.
# User 158: Rakhmanov_Aleksandr
# Got 37 games.
# User 159: Aeroplanino7
# Got 0 games.
# User 160: SGchess01
# Got 0 games.
# User 161: RaskolnikovRebel
# Got 21 games.
# User 162: VerveeldeSpeedrun
# Got 443 games.
# User 163: AParadiseLost
# Got 0 games.
# User 164: venajalainen
# Got 5 games.
# User 165: ReluctantCannibal
# Got 0 games.
# User 166: abhijeet1610
# Got 0 games.
# User 167: StepOnMeSydneSweeney
# Got 1 games.
# User 168: VladimirMarkovic
# Got 0 games.
# User 169: ggwellplayedboi
# Got 0 games.
# User 170: Roman2001
# Got 10 games.
# Error parsing move Nd7: expected uci string to be of length 4 or 5: 'Nd7'
# User 171: theprodigco
# Got 24 games.
# User 172: hanyabdo2
# Got 349 games.
# User 173: rascarcapac87
# Got 1152 games.
# User 174: Yazet_Mazalbloom
# Got 0 games.
# User 175: KhBegmuratov
# Got 1 games.
# User 176: Guary1
# Got 31 games.
# User 177: e4_c5_c3-1-0
# Got 95 games.
# User 178: Ali_rastbod
# Got 19 games.
# User 179: chessmaster2006
# Got 12 games.
# User 180: Ya_Ilya
# Got 202 games.
# User 181: Chess_for_some
# Got 779 games.
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# User 182: vaynetop
# Got 0 games.
# User 183: Raph_Desbiens
# Got 334 games.
# User 184: tuntematon
# Got 11 games.
# User 185: datajunkie
# Got 41 games.
# User 186: Dr-CRO
# Got 0 games.
# User 187: WOLFNIGHTAERR
# Got 0 games.
# User 188: Eyesless18
# Got 1 games.
# User 189: NEWn2004
# Got 38 games.
# User 190: aboudey
# Got 261 games.
# User 191: Schemato
# Got 2383 games.
# User 192: grind_neverstops
# Got 0 games.
# User 193: Art-Vega
# Got 3977 games.
# User 194: Milchakov_Andrey
# Got 163 games.
# User 195: woshigeshagua
# Got 0 games.
# User 196: Sergo-Vladivostok
# Got 10 games.
# User 197: AnythingButAverage
# Got 0 games.
# User 198: Thorbiddles
# Got 515 games.
# Error parsing move Ne3: expected uci string to be of length 4 or 5: 'Ne3'
# Error parsing move Be3: expected uci string to be of length 4 or 5: 'Be3'
# Error parsing move Bb5: expected uci string to be of length 4 or 5: 'Bb5'
# Error parsing move Bb5: expected uci string to be of length 4 or 5: 'Bb5'
# Error parsing move Bb5: expected uci string to be of length 4 or 5: 'Bb5'
# Error parsing move Bb5: expected uci string to be of length 4 or 5: 'Bb5'
# Error parsing move Bb5: expected uci string to be of length 4 or 5: 'Bb5'
# Error parsing move Rxd1: invalid uci: 'Rxd1'
# Error parsing move Rxd1: invalid uci: 'Rxd1'
# Error parsing move Kxg2: invalid uci: 'Kxg2'
# Error parsing move Kxg2: invalid uci: 'Kxg2'
# Error parsing move Kxg2: invalid uci: 'Kxg2'
# Error parsing move Kc2: expected uci string to be of length 4 or 5: 'Kc2'
# Error parsing move Kc2: expected uci string to be of length 4 or 5: 'Kc2'
# Error parsing move Kd4: expected uci string to be of length 4 or 5: 'Kd4'
# Error parsing move Kd4: expected uci string to be of length 4 or 5: 'Kd4'
# Error parsing move Kd4: expected uci string to be of length 4 or 5: 'Kd4'
# Error parsing move Qh2+: invalid uci: 'Qh2+'
# Error parsing move Qe8+: invalid uci: 'Qe8+'
# Error parsing move Rc6: expected uci string to be of length 4 or 5: 'Rc6'
# Error parsing move Rc3+: invalid uci: 'Rc3+'
# Error parsing move Rf2: expected uci string to be of length 4 or 5: 'Rf2'
# Error parsing move Rf2: expected uci string to be of length 4 or 5: 'Rf2'
# Error parsing move Rf3: expected uci string to be of length 4 or 5: 'Rf3'
# Error parsing move Rf3: expected uci string to be of length 4 or 5: 'Rf3'
# Error parsing move Bd8+: invalid uci: 'Bd8+'
# Error parsing move Bd8+: invalid uci: 'Bd8+'
# Error parsing move Bd8+: invalid uci: 'Bd8+'
# Error parsing move Bb6: expected uci string to be of length 4 or 5: 'Bb6'
# User 199: Peacefulwarrior1996
# Got 51 games.
# User 200: capochess
# Got 0 games.
# User 201: BrittaBagels
# Got 0 games.
# User 202: Tictoocchess
# Got 381 games.
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# User 203: Delebarre
# Got 477 games.
# User 204: RE-BORN
# Got 114 games.
# User 205: CK-king-2024
# Got 0 games.
# User 206: fogof
# Got 544 games.
# User 207: LoeweOpta
# Got 922 games.
# User 208: BrokyLoveKFC
# Got 1 games.
# User 209: LANCELOT_06
# Got 11 games.
# User 210: nepoo1392
# Got 60 games.
# User 211: GK1963
# Got 0 games.
# User 212: SpeedMonkey
# Got 195 games.
# User 213: Squaretaker
# Got 1012 games.
# User 214: Bagautdin
# Got 33 games.
# User 215: LuckyGraaf
# Got 30 games.
# User 216: OCChess
# Got 0 games.
# User 217: GMVallejo
# Got 0 games.
# User 218: typical_dolba4
# Got 0 games.
# User 219: CzemuGraszNaWajche
# Got 0 games.
# User 220: Night-King96
# Got 0 games.
# User 221: WillyCasanova
# Got 4 games.
# Error parsing move Qc7: expected uci string to be of length 4 or 5: 'Qc7'
# Error parsing move Qc7: expected uci string to be of length 4 or 5: 'Qc7'
# User 222: AntiberserkM
# Got 173 games.
# User 223: Aligabler
# Got 125 games.
# User 224: sylvlondon
# Got 164 games.
# User 225: Slek
# Got 96 games.
# Error parsing move e4: expected uci string to be of length 4 or 5: 'e4'
# User 226: khalidezz269
# Got 0 games.
# User 227: albowiem
# Got 20 games.
# User 228: Training_Account123
# Got 6 games.
# User 229: mane27
# Got 177 games.
# Error parsing move Rd8: expected uci string to be of length 4 or 5: 'Rd8'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move e3: expected uci string to be of length 4 or 5: 'e3'
# Error parsing move e3: expected uci string to be of length 4 or 5: 'e3'
# Error parsing move h3: expected uci string to be of length 4 or 5: 'h3'
# Error parsing move b6: expected uci string to be of length 4 or 5: 'b6'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move Nd7: expected uci string to be of length 4 or 5: 'Nd7'
# Error parsing move Bb7: expected uci string to be of length 4 or 5: 'Bb7'
# Error parsing move Bc5: expected uci string to be of length 4 or 5: 'Bc5'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move Rc8: expected uci string to be of length 4 or 5: 'Rc8'
# Error parsing move Bxc1: invalid uci: 'Bxc1'
# Error parsing move Nd7: expected uci string to be of length 4 or 5: 'Nd7'
# Error parsing move Nc6: expected uci string to be of length 4 or 5: 'Nc6'
# Error parsing move Bh4: expected uci string to be of length 4 or 5: 'Bh4'
# Error parsing move exd4: invalid uci: 'exd4'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move cxd5: invalid uci: 'cxd5'
# Error parsing move a4: expected uci string to be of length 4 or 5: 'a4'
# Error parsing move e4: expected uci string to be of length 4 or 5: 'e4'
# Error parsing move e3: expected uci string to be of length 4 or 5: 'e3'
# Error parsing move Bg7: expected uci string to be of length 4 or 5: 'Bg7'
# Error parsing move c6: expected uci string to be of length 4 or 5: 'c6'
# Error parsing move Bg5: expected uci string to be of length 4 or 5: 'Bg5'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move b6: expected uci string to be of length 4 or 5: 'b6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move Nc6: expected uci string to be of length 4 or 5: 'Nc6'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move b4: expected uci string to be of length 4 or 5: 'b4'
# Error parsing move Ra4: expected uci string to be of length 4 or 5: 'Ra4'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move exf4: invalid uci: 'exf4'
# Error parsing move Nc6: expected uci string to be of length 4 or 5: 'Nc6'
# Error parsing move b5: expected uci string to be of length 4 or 5: 'b5'
# Error parsing move exf4: invalid uci: 'exf4'
# Error parsing move b6: expected uci string to be of length 4 or 5: 'b6'
# Error parsing move f4: expected uci string to be of length 4 or 5: 'f4'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move Re1: expected uci string to be of length 4 or 5: 'Re1'
# Error parsing move c4: expected uci string to be of length 4 or 5: 'c4'
# Error parsing move e5: expected uci string to be of length 4 or 5: 'e5'
# Error parsing move Nc6: expected uci string to be of length 4 or 5: 'Nc6'
# Error parsing move e5: expected uci string to be of length 4 or 5: 'e5'
# Error parsing move Bb4: expected uci string to be of length 4 or 5: 'Bb4'
# Error parsing move c3: expected uci string to be of length 4 or 5: 'c3'
# Error parsing move Qg3: expected uci string to be of length 4 or 5: 'Qg3'
# Error parsing move c3: expected uci string to be of length 4 or 5: 'c3'
# Error parsing move e5: expected uci string to be of length 4 or 5: 'e5'
# Error parsing move exd5: invalid uci: 'exd5'
# Error parsing move Bc5: expected uci string to be of length 4 or 5: 'Bc5'
# Error parsing move b5: expected uci string to be of length 4 or 5: 'b5'
# Error parsing move c3: expected uci string to be of length 4 or 5: 'c3'
# Error parsing move c3: expected uci string to be of length 4 or 5: 'c3'
# Error parsing move a4: expected uci string to be of length 4 or 5: 'a4'
# Error parsing move e5: expected uci string to be of length 4 or 5: 'e5'
# Error parsing move d4: expected uci string to be of length 4 or 5: 'd4'
# Error parsing move Bg5: expected uci string to be of length 4 or 5: 'Bg5'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move e3: expected uci string to be of length 4 or 5: 'e3'
# Error parsing move c3: expected uci string to be of length 4 or 5: 'c3'
# Error parsing move Re1+: invalid uci: 'Re1+'
# Error parsing move c5: expected uci string to be of length 4 or 5: 'c5'
# Error parsing move f4: expected uci string to be of length 4 or 5: 'f4'
# Error parsing move c3: expected uci string to be of length 4 or 5: 'c3'
# Error parsing move Nb6: expected uci string to be of length 4 or 5: 'Nb6'
# Error parsing move Nd5: expected uci string to be of length 4 or 5: 'Nd5'
# Error parsing move Nxc5: invalid uci: 'Nxc5'
# Error parsing move c4: expected uci string to be of length 4 or 5: 'c4'
# Error parsing move e5: expected uci string to be of length 4 or 5: 'e5'
# Error parsing move d4: expected uci string to be of length 4 or 5: 'd4'
# Error parsing move Nxd4: invalid uci: 'Nxd4'
# Error parsing move Nd4: expected uci string to be of length 4 or 5: 'Nd4'
# Error parsing move Rf8: expected uci string to be of length 4 or 5: 'Rf8'
# Error parsing move Be7: expected uci string to be of length 4 or 5: 'Be7'
# Error parsing move Bxe6: invalid uci: 'Bxe6'
# Error parsing move d4: expected uci string to be of length 4 or 5: 'd4'
# Error parsing move Bd8: expected uci string to be of length 4 or 5: 'Bd8'
# Error parsing move e5: expected uci string to be of length 4 or 5: 'e5'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move dxe4: invalid uci: 'dxe4'
# Error parsing move O-O: expected uci string to be of length 4 or 5: 'O-O'
# Error parsing move Nf4: expected uci string to be of length 4 or 5: 'Nf4'
# Error parsing move Be7: expected uci string to be of length 4 or 5: 'Be7'
# Error parsing move Nb6: expected uci string to be of length 4 or 5: 'Nb6'
# Error parsing move Qc7: expected uci string to be of length 4 or 5: 'Qc7'
# Error parsing move Nd5: expected uci string to be of length 4 or 5: 'Nd5'
# Error parsing move exd5: invalid uci: 'exd5'
# Error parsing move Rc2: expected uci string to be of length 4 or 5: 'Rc2'
# User 230: Abyin2000
# Got 1354 games.
# User 231: ANRI55
# Got 161 games.
# User 232: Knight_Rider13
# Got 50 games.
# User 233: athena-pallada
# Got 164 games.
# User 234: Pavel-Vorontsov
# Got 78 games.
# User 235: CGK_ARCA
# Got 6 games.
# User 236: BoardDemon
# Got 0 games.
# User 237: Konnov_Oleg
# Got 1212 games.
# Error parsing move e5: expected uci string to be of length 4 or 5: 'e5'
# Error parsing move c5: expected uci string to be of length 4 or 5: 'c5'
# User 238: JordanSNK
# Got 7 games.
# User 239: edziomobil
# Got 19 games.
# User 240: RoDoSfAtiHi
# Got 4 games.
# User 241: Secret_Spion
# Got 0 games.
# User 242: Tactic_Trainer2023
# Got 0 games.
# User 243: GwapingsAttack2002
# Got 174 games.
# User 244: papasi
# Got 223 games.
# User 245: master3443
# Got 0 games.
# User 246: Dr_mARtIk
# Got 0 games.
# User 247: AKing2024
# Got 0 games.
# User 248: indianstar
# Got 0 games.
# User 249: pavlito83
# Got 148 games.
# User 250: ManulPalace
# Got 0 games.
# User 251: DungeonMeister
# Got 15 games.
# User 252: Kinryln
# Got 0 games.
# User 253: kingnb
# Got 13 games.
# User 254: Medvedpoint
# Got 25 games.
# User 255: Chesstrix01
# Got 259 games.
# User 256: Blackmin96
# Got 10 games.
# User 257: killerbean10
# Got 27 games.
# User 258: Chesstoday
# Got 8 games.
# User 259: SylvanasWindRunner12
# Got 0 games.
# User 260: Mo_FanXue
# Got 0 games.
# User 261: WillyJohnson
# Got 239 games.
# User 262: dawid1398
# Got 13 games.
# User 263: pingshenmeyaoshiwang
# Got 2 games.
# User 264: Hungry_Dragon
# Got 60 games.
# Error parsing move e4: expected uci string to be of length 4 or 5: 'e4'
# User 265: brewmasterua
# Got 0 games.
# User 266: Eemir-2006
# Got 0 games.
# User 267: kilav2006
# Got 377 games.
# User 268: Aborigen100500
# Got 1454 games.
# User 269: Romaa2011
# Got 41 games.
# User 270: bssh
# Got 323 games.
# User 271: Ernur2008
# Got 0 games.
# User 272: ranibow_ghost
# Got 0 games.
# User 273: feeblad
# Got 13 games.
# User 274: FastforYou
# Got 0 games.
# User 275: avcs
# Got 378 games.
# Error parsing move b5: expected uci string to be of length 4 or 5: 'b5'
# Error parsing move b5: expected uci string to be of length 4 or 5: 'b5'
# User 276: Masikskai
# Got 0 games.
# User 277: Oganian_Miran
# Got 6 games.
# User 278: Negocia
# Got 0 games.
# User 279: meshmuhammad
# Got 2 games.
# User 280: Mandarlad17
# Got 1 games.
# User 281: Siyay_25
# Got 15 games.
# Error parsing move e5: expected uci string to be of length 4 or 5: 'e5'
# User 282: SashaKuzhilniy
# Got 2 games.
# User 283: NorthWind05
# Got 0 games.
# User 284: justwannamakeastudy
# Got 74 games.
# User 285: BIZOO
# Got 71 games.
# User 286: leartt
# Got 144 games.
# User 287: forshmakoff
# Got 0 games.
# User 288: Vlad_G92
# Got 277 games.
# User 289: Bonitta
# Got 45 games.
# User 290: ChessK1ng15
# Got 0 games.
# User 291: JurgenSanchez97
# Got 0 games.
# User 292: chess_228
# Got 189 games.
# User 293: Truemasterme
# Got 274 games.
# Error parsing move g7: expected uci string to be of length 4 or 5: 'g7'
# Error parsing move Ra3: expected uci string to be of length 4 or 5: 'Ra3'
# Error parsing move Ra2+: invalid uci: 'Ra2+'
# Error parsing move Nxa7: invalid uci: 'Nxa7'
# Error parsing move Rxf7+: invalid uci: 'Rxf7+'
# Error parsing move Kd3: expected uci string to be of length 4 or 5: 'Kd3'
# Error parsing move Kd4: expected uci string to be of length 4 or 5: 'Kd4'
# Error parsing move h5: expected uci string to be of length 4 or 5: 'h5'
# Error parsing move Qxc6+: invalid uci: 'Qxc6+'
# Error parsing move Qc7: expected uci string to be of length 4 or 5: 'Qc7'
# Error parsing move O-O: expected uci string to be of length 4 or 5: 'O-O'
# Error parsing move O-O: expected uci string to be of length 4 or 5: 'O-O'
# Error parsing move Bxg7+: invalid uci: 'Bxg7+'
# Error parsing move Qf8+: invalid uci: 'Qf8+'
# Error parsing move Qf1: expected uci string to be of length 4 or 5: 'Qf1'
# User 294: ConwyCastle
# Got 3908 games.
# User 295: Azadi_Am
# Got 0 games.
# User 296: mastermindok
# Got 221 games.
# User 297: ChessTutorAI
# Got 0 games.
# User 298: Zikator
# Got 0 games.
# User 299: wizard98
# Got 0 games.
# User 300: vistagusta
# Got 0 games.
# User 301: Ferran1850
# Got 3 games.
# Error parsing move a4: expected uci string to be of length 4 or 5: 'a4'
# User 302: Brilliant_Bishop
# Got 233 games.
# User 303: ChessTactics28
# Got 52 games.
# User 304: Didici12
# Got 37 games.
# User 305: ishir1212
# Got 6 games.
# User 306: vlad10898
# Got 2 games.
# User 307: Alexandr_KhleBovich
# Got 61 games.
# Error parsing move Qxf7#: invalid uci: 'Qxf7#'
# Error parsing move Qxf7#: invalid uci: 'Qxf7#'
# User 308: evg85
# Got 141 games.
# User 309: Aljarrah_Laith04
# Got 0 games.
# User 310: OX528354
# Got 0 games.
# User 311: Humanchesscoach
# Got 1 games.
# User 312: OjaiJoao
# Got 786 games.
# User 313: drakoplas
# Got 317 games.
# Error parsing move Na3: expected uci string to be of length 4 or 5: 'Na3'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move dxc4: invalid uci: 'dxc4'
# Error parsing move dxc4: invalid uci: 'dxc4'
# Error parsing move dxc4: invalid uci: 'dxc4'
# Error parsing move dxc4: invalid uci: 'dxc4'
# Error parsing move dxc4: invalid uci: 'dxc4'
# Error parsing move dxc4: invalid uci: 'dxc4'
# Error parsing move cxb5: invalid uci: 'cxb5'
# Error parsing move cxb5: invalid uci: 'cxb5'
# Error parsing move cxb5: invalid uci: 'cxb5'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move cxb5: invalid uci: 'cxb5'
# Error parsing move cxb5: invalid uci: 'cxb5'
# Error parsing move cxb5: invalid uci: 'cxb5'
# Error parsing move Qc2: expected uci string to be of length 4 or 5: 'Qc2'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move cxb5: invalid uci: 'cxb5'
# User 314: Krishnarjun-Mitra
# Got 0 games.
# User 315: uSeRnAmEnOtAvAiL
# Got 0 games.
# User 316: jthain1
# Got 844 games.
# User 317: Dmitriychesser
# Got 0 games.
# User 318: Armenian_ChessMaster
# Got 0 games.
# User 319: chickenrun2024
# Got 57 games.
# User 320: jbr9
# Got 160 games.
# User 321: Queribus
# Got 551 games.
# User 322: Qualitychess4ever
# Got 9 games.
# User 323: josedavid321
# Got 128 games.
# User 324: BigMacx
# Got 41 games.
# User 325: crazyblue29
# Got 348 games.
# User 326: Moro182
# Got 3 games.
# User 327: Nozdrachev_Vladislav
# Got 652 games.
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move dxc3: invalid uci: 'dxc3'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move Ne4: expected uci string to be of length 4 or 5: 'Ne4'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move Ng8: expected uci string to be of length 4 or 5: 'Ng8'
# Error parsing move e3: expected uci string to be of length 4 or 5: 'e3'
# Error parsing move e3: expected uci string to be of length 4 or 5: 'e3'
# Error parsing move e3: expected uci string to be of length 4 or 5: 'e3'
# Error parsing move e4: expected uci string to be of length 4 or 5: 'e4'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move e3: expected uci string to be of length 4 or 5: 'e3'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move e4: expected uci string to be of length 4 or 5: 'e4'
# Error parsing move e3: expected uci string to be of length 4 or 5: 'e3'
# Error parsing move e3: expected uci string to be of length 4 or 5: 'e3'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move e3: expected uci string to be of length 4 or 5: 'e3'
# Error parsing move e4: expected uci string to be of length 4 or 5: 'e4'
# Error parsing move e4: expected uci string to be of length 4 or 5: 'e4'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move e3: expected uci string to be of length 4 or 5: 'e3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move e4: expected uci string to be of length 4 or 5: 'e4'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move e3: expected uci string to be of length 4 or 5: 'e3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move cxd5: invalid uci: 'cxd5'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move e3: expected uci string to be of length 4 or 5: 'e3'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move c5: expected uci string to be of length 4 or 5: 'c5'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move g6: expected uci string to be of length 4 or 5: 'g6'
# Error parsing move Nc6: expected uci string to be of length 4 or 5: 'Nc6'
# Error parsing move c5: expected uci string to be of length 4 or 5: 'c5'
# Error parsing move c5: expected uci string to be of length 4 or 5: 'c5'
# Error parsing move c5: expected uci string to be of length 4 or 5: 'c5'
# Error parsing move c5: expected uci string to be of length 4 or 5: 'c5'
# Error parsing move e6: expected uci string to be of length 4 or 5: 'e6'
# Error parsing move c5: expected uci string to be of length 4 or 5: 'c5'
# Error parsing move Nc6: expected uci string to be of length 4 or 5: 'Nc6'
# Error parsing move g6: expected uci string to be of length 4 or 5: 'g6'
# Error parsing move e6: expected uci string to be of length 4 or 5: 'e6'
# Error parsing move Nc6: expected uci string to be of length 4 or 5: 'Nc6'
# Error parsing move Nc6: expected uci string to be of length 4 or 5: 'Nc6'
# Error parsing move d4: expected uci string to be of length 4 or 5: 'd4'
# Error parsing move c5: expected uci string to be of length 4 or 5: 'c5'
# Error parsing move Qf3+: invalid uci: 'Qf3+'
# Error parsing move Qf3+: invalid uci: 'Qf3+'
# Error parsing move Qh5+: invalid uci: 'Qh5+'
# Error parsing move Bxd5+: invalid uci: 'Bxd5+'
# Error parsing move Qf3+: invalid uci: 'Qf3+'
# Error parsing move Qf3+: invalid uci: 'Qf3+'
# Error parsing move Qf3+: invalid uci: 'Qf3+'
# Error parsing move Qf3+: invalid uci: 'Qf3+'
# Error parsing move Qf3+: invalid uci: 'Qf3+'
# Error parsing move Qf3+: invalid uci: 'Qf3+'
# Error parsing move Qf3+: invalid uci: 'Qf3+'
# Error parsing move Qf3+: invalid uci: 'Qf3+'
# Error parsing move O-O: expected uci string to be of length 4 or 5: 'O-O'
# Error parsing move Qf3+: invalid uci: 'Qf3+'
# Error parsing move Qf3+: invalid uci: 'Qf3+'
# Error parsing move gxf4: invalid uci: 'gxf4'
# Error parsing move gxf4: invalid uci: 'gxf4'
# Error parsing move gxf4: invalid uci: 'gxf4'
# Error parsing move gxf4: invalid uci: 'gxf4'
# Error parsing move gxf4: invalid uci: 'gxf4'
# Error parsing move gxf4: invalid uci: 'gxf4'
# Error parsing move gxf4: invalid uci: 'gxf4'
# Error parsing move gxf4: invalid uci: 'gxf4'
# Error parsing move gxf4: invalid uci: 'gxf4'
# Error parsing move gxf4: invalid uci: 'gxf4'
# Error parsing move gxf4: invalid uci: 'gxf4'
# Error parsing move gxf4: invalid uci: 'gxf4'
# Error parsing move gxf4: invalid uci: 'gxf4'
# Error parsing move gxf4: invalid uci: 'gxf4'
# Error parsing move a6: expected uci string to be of length 4 or 5: 'a6'
# Error parsing move Bc5: expected uci string to be of length 4 or 5: 'Bc5'
# Error parsing move a6: expected uci string to be of length 4 or 5: 'a6'
# Error parsing move a6: expected uci string to be of length 4 or 5: 'a6'
# Error parsing move a6: expected uci string to be of length 4 or 5: 'a6'
# Error parsing move a6: expected uci string to be of length 4 or 5: 'a6'
# Error parsing move a6: expected uci string to be of length 4 or 5: 'a6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move a6: expected uci string to be of length 4 or 5: 'a6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move a6: expected uci string to be of length 4 or 5: 'a6'
# Error parsing move a6: expected uci string to be of length 4 or 5: 'a6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move a6: expected uci string to be of length 4 or 5: 'a6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move a6: expected uci string to be of length 4 or 5: 'a6'
# Error parsing move f5: expected uci string to be of length 4 or 5: 'f5'
# Error parsing move Nd4: expected uci string to be of length 4 or 5: 'Nd4'
# Error parsing move f5: expected uci string to be of length 4 or 5: 'f5'
# Error parsing move a6: expected uci string to be of length 4 or 5: 'a6'
# Error parsing move d6: expected uci string to be of length 4 or 5: 'd6'
# Error parsing move Nd4: expected uci string to be of length 4 or 5: 'Nd4'
# Error parsing move Bc5: expected uci string to be of length 4 or 5: 'Bc5'
# Error parsing move a6: expected uci string to be of length 4 or 5: 'a6'
# Error parsing move a6: expected uci string to be of length 4 or 5: 'a6'
# Error parsing move a6: expected uci string to be of length 4 or 5: 'a6'
# Error parsing move e3: expected uci string to be of length 4 or 5: 'e3'
# Error parsing move g3: expected uci string to be of length 4 or 5: 'g3'
# Error parsing move e3: expected uci string to be of length 4 or 5: 'e3'
# Error parsing move a3: expected uci string to be of length 4 or 5: 'a3'
# Error parsing move Bd2: expected uci string to be of length 4 or 5: 'Bd2'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move e3: expected uci string to be of length 4 or 5: 'e3'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move Bd2: expected uci string to be of length 4 or 5: 'Bd2'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move e3: expected uci string to be of length 4 or 5: 'e3'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move Qc2: expected uci string to be of length 4 or 5: 'Qc2'
# Error parsing move Bd2: expected uci string to be of length 4 or 5: 'Bd2'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move a3: expected uci string to be of length 4 or 5: 'a3'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move e3: expected uci string to be of length 4 or 5: 'e3'
# Error parsing move Bg5: expected uci string to be of length 4 or 5: 'Bg5'
# Error parsing move e3: expected uci string to be of length 4 or 5: 'e3'
# Error parsing move Nf3: expected uci string to be of length 4 or 5: 'Nf3'
# Error parsing move Qc2: expected uci string to be of length 4 or 5: 'Qc2'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move b6: expected uci string to be of length 4 or 5: 'b6'
# Error parsing move b6: expected uci string to be of length 4 or 5: 'b6'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move g6: expected uci string to be of length 4 or 5: 'g6'
# Error parsing move g6: expected uci string to be of length 4 or 5: 'g6'
# Error parsing move b6: expected uci string to be of length 4 or 5: 'b6'
# Error parsing move g6: expected uci string to be of length 4 or 5: 'g6'
# Error parsing move d6: expected uci string to be of length 4 or 5: 'd6'
# Error parsing move e6: expected uci string to be of length 4 or 5: 'e6'
# Error parsing move g6: expected uci string to be of length 4 or 5: 'g6'
# Error parsing move d6: expected uci string to be of length 4 or 5: 'd6'
# Error parsing move e6: expected uci string to be of length 4 or 5: 'e6'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move c5: expected uci string to be of length 4 or 5: 'c5'
# Error parsing move d6: expected uci string to be of length 4 or 5: 'd6'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move g6: expected uci string to be of length 4 or 5: 'g6'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move g6: expected uci string to be of length 4 or 5: 'g6'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move g6: expected uci string to be of length 4 or 5: 'g6'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move a6: expected uci string to be of length 4 or 5: 'a6'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move Bg7: expected uci string to be of length 4 or 5: 'Bg7'
# Error parsing move Bg7: expected uci string to be of length 4 or 5: 'Bg7'
# Error parsing move Bg7: expected uci string to be of length 4 or 5: 'Bg7'
# Error parsing move Bg7: expected uci string to be of length 4 or 5: 'Bg7'
# Error parsing move Bg7: expected uci string to be of length 4 or 5: 'Bg7'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move Bg7: expected uci string to be of length 4 or 5: 'Bg7'
# Error parsing move Bg7: expected uci string to be of length 4 or 5: 'Bg7'
# Error parsing move Bg7: expected uci string to be of length 4 or 5: 'Bg7'
# Error parsing move d6: expected uci string to be of length 4 or 5: 'd6'
# Error parsing move Bg7: expected uci string to be of length 4 or 5: 'Bg7'
# Error parsing move Bg7: expected uci string to be of length 4 or 5: 'Bg7'
# Error parsing move Bg7: expected uci string to be of length 4 or 5: 'Bg7'
# Error parsing move Bg7: expected uci string to be of length 4 or 5: 'Bg7'
# Error parsing move Bg7: expected uci string to be of length 4 or 5: 'Bg7'
# Error parsing move Bg7: expected uci string to be of length 4 or 5: 'Bg7'
# Error parsing move Bg7: expected uci string to be of length 4 or 5: 'Bg7'
# Error parsing move Bg7: expected uci string to be of length 4 or 5: 'Bg7'
# Error parsing move Bg7: expected uci string to be of length 4 or 5: 'Bg7'
# Error parsing move d6: expected uci string to be of length 4 or 5: 'd6'
# Error parsing move Bg7: expected uci string to be of length 4 or 5: 'Bg7'
# Error parsing move Bg7: expected uci string to be of length 4 or 5: 'Bg7'
# Error parsing move f5: expected uci string to be of length 4 or 5: 'f5'
# Error parsing move c3: expected uci string to be of length 4 or 5: 'c3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move c4: expected uci string to be of length 4 or 5: 'c4'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Bd3: expected uci string to be of length 4 or 5: 'Bd3'
# Error parsing move Bd3: expected uci string to be of length 4 or 5: 'Bd3'
# Error parsing move c4: expected uci string to be of length 4 or 5: 'c4'
# Error parsing move c4: expected uci string to be of length 4 or 5: 'c4'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Bd3: expected uci string to be of length 4 or 5: 'Bd3'
# Error parsing move Bd3: expected uci string to be of length 4 or 5: 'Bd3'
# Error parsing move Bd3: expected uci string to be of length 4 or 5: 'Bd3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Bd3: expected uci string to be of length 4 or 5: 'Bd3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Bf4: expected uci string to be of length 4 or 5: 'Bf4'
# Error parsing move Bd3: expected uci string to be of length 4 or 5: 'Bd3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Bd3: expected uci string to be of length 4 or 5: 'Bd3'
# Error parsing move Bd3: expected uci string to be of length 4 or 5: 'Bd3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move c4: expected uci string to be of length 4 or 5: 'c4'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move Bc5: expected uci string to be of length 4 or 5: 'Bc5'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move exf4: invalid uci: 'exf4'
# Error parsing move exf4: invalid uci: 'exf4'
# Error parsing move exf4: invalid uci: 'exf4'
# Error parsing move exf4: invalid uci: 'exf4'
# Error parsing move Nc6: expected uci string to be of length 4 or 5: 'Nc6'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move exf4: invalid uci: 'exf4'
# Error parsing move exf4: invalid uci: 'exf4'
# Error parsing move Nc6: expected uci string to be of length 4 or 5: 'Nc6'
# Error parsing move exf4: invalid uci: 'exf4'
# Error parsing move exf4: invalid uci: 'exf4'
# Error parsing move d6: expected uci string to be of length 4 or 5: 'd6'
# Error parsing move exf4: invalid uci: 'exf4'
# Error parsing move exf4: invalid uci: 'exf4'
# Error parsing move f3: expected uci string to be of length 4 or 5: 'f3'
# Error parsing move Be3: expected uci string to be of length 4 or 5: 'Be3'
# Error parsing move Be3: expected uci string to be of length 4 or 5: 'Be3'
# Error parsing move Be3: expected uci string to be of length 4 or 5: 'Be3'
# Error parsing move Be3: expected uci string to be of length 4 or 5: 'Be3'
# Error parsing move Be3: expected uci string to be of length 4 or 5: 'Be3'
# Error parsing move Be3: expected uci string to be of length 4 or 5: 'Be3'
# Error parsing move g3: expected uci string to be of length 4 or 5: 'g3'
# Error parsing move Be3: expected uci string to be of length 4 or 5: 'Be3'
# Error parsing move Be3: expected uci string to be of length 4 or 5: 'Be3'
# Error parsing move Be3: expected uci string to be of length 4 or 5: 'Be3'
# Error parsing move Bc4: expected uci string to be of length 4 or 5: 'Bc4'
# Error parsing move Be2: expected uci string to be of length 4 or 5: 'Be2'
# Error parsing move Be3: expected uci string to be of length 4 or 5: 'Be3'
# Error parsing move Be3: expected uci string to be of length 4 or 5: 'Be3'
# Error parsing move h4: expected uci string to be of length 4 or 5: 'h4'
# Error parsing move Be3: expected uci string to be of length 4 or 5: 'Be3'
# Error parsing move h4: expected uci string to be of length 4 or 5: 'h4'
# Error parsing move Be2: expected uci string to be of length 4 or 5: 'Be2'
# Error parsing move Bb5+: invalid uci: 'Bb5+'
# Error parsing move Bg5: expected uci string to be of length 4 or 5: 'Bg5'
# Error parsing move Be3: expected uci string to be of length 4 or 5: 'Be3'
# Error parsing move Bf4: expected uci string to be of length 4 or 5: 'Bf4'
# Error parsing move Bg5: expected uci string to be of length 4 or 5: 'Bg5'
# ...
# User 535: EmmaCretescu
# Got 0 games.
# User 536: Mitrabha
# Got 13 games.
# User 537: Bigboss2037
# Got 32 games.
# User 538: rob188
# Got 110 games.
# User 539: Peligro_98
# Got 3 games.
# User 540: calcu_later
# Got 32 games.
# User 541: Prohorov_2010
# Got 41 games.
# User 542: JamesHardey
# Got 0 games.
# User 543: Sigma_Tauri
# Got 0 games.
# User 544: VariantsOnly
# Got 77 games.
# User 545: Patetico
# Got 0 games.
# User 546: IcelandAire
# Got 301 games.
# User 547: HomayooonT
# Got 11 games.
# User 548: Guragat
# Got 147 games.
# User 549: TemurKuybokarov
# Got 26 games.
# User 550: Misterchess64
# Got 0 games.
# User 551: MarianoFreyreX_2024
# Got 0 games.
# User 552: kormoran_HG
# Got 95 games.
# User 553: dmitrijiiiGM
# Got 23 games.
# User 554: TacticNinja_2010
# Got 106 games.
# User 555: sotirakis
# Got 30 games.
# User 556: SlupSer_From_SPB
# Got 23 games.
# User 557: komodo54
# Got 15 games.
# User 558: chunihardt128
# Got 181 games.
# User 559: MATRIXTRINITY
# Got 2 games.
# User 560: Zaven_ChessMood
# Got 7 games.
# User 561: sahlacretzu
# Got 0 games.
# User 562: TuloyPaRin2023
# Got 163 games.
# User 563: BulletTrainTo2950
# Got 0 games.
# User 564: Tigran-Harutyunyan
# Got 0 games.
# User 565: youblockedme
# Got 44 games.
# User 566: RubiRedhead
# Got 38 games.
# User 567: Baidetskyi_Valentin
# Got 4 games.
# User 568: gmbarbosachess
# Got 34 games.
# User 569: Alex_Soelden
# Got 0 games.
# User 570: anonymousblitz
# Got 1 games.
# User 571: Multibrendovyi
# Got 68 games.
# User 572: AllahsBlessing
# Got 3 games.
# User 573: Noves
# Got 659 games.
# User 574: smihir6
# Got 0 games.
# User 575: jhaybolado
# Got 602 games.
# User 576: mohaamedd21k
# Got 8 games.
# User 577: zeronine
# Got 3 games.
# User 578: BackRankTank
# Got 1 games.
# User 579: vvchessli
# Got 146 games.
# User 580: Matlakov
# Got 0 games.
# User 581: TonyGazzo
# Got 0 games.
# User 582: Artoo
# Got 149 games.
# User 583: iourique
# Got 0 games.
# User 584: ketan404
# Got 983 games.
# User 585: Yhwach_Almighty2003
# Got 152 games.
# User 586: Alexshirov
# Got 415 games.
# User 587: Fandorine96
# Got 64 games.
# User 588: plevok228
# Got 1 games.
# User 589: darkness_24
# Got 51 games.
# User 590: TraderDeportivo
# Got 2 games.
# User 591: JIANGHAOCHEN
# Got 36 games.
# User 592: Lintchevski_Daniil
# Got 0 games.
# User 593: SindarovGM
# Got 17 games.
# User 594: TAAnderson
# Got 2 games.
# User 595: EltajSafarli
# Got 204 games.
# User 596: AbasovN
# Got 56 games.
# User 597: Vihajaisestatulesta
# Got 70 games.
# User 598: jjpineda
# Got 362 games.
# User 599: spartan_mentality
# Got 0 games.
# User 600: Pap-G
# Got 158 games.
# User 601: L3bron_James23
# Got 19 games.
# User 602: Ngandung
# Got 1318 games.
# User 603: GoldenFirebird
# Got 5 games.
# User 604: slamdunk_09
# Got 0 games.
# User 605: AndrewHoma
# Got 7 games.
# User 606: IVK88
# Got 21 games.
# User 607: A1NUR
# Got 764 games.
# User 608: NeverEnough
# Got 0 games.
# User 609: HaalandSmecherul
# Got 0 games.
# User 610: Xiaozu
# Got 0 games.
# User 611: Arseniii_Nesterov
# Got 6 games.
# User 612: nilete
# Got 1167 games.
# User 613: WorkTim1
# Got 0 games.
# User 614: untracked_capy
# Got 0 games.
# User 615: Marat22121972
# Got 66 games.
# User 616: msb2
# Got 25 games.
# User 617: MrUltra123
# Got 1 games.
# User 618: MarkosianDavid
# Got 262 games.
# User 619: Eagle_2019
# Got 1 games.
# User 620: greennight
# Got 18 games.
# User 621: RubiPengui
# Got 180 games.
# User 622: BongKasan
# Got 175 games.
# User 623: Abgdezeyyyy
# Got 0 games.
# User 624: pelmen1985
# Got 2187 games.
# User 625: rs69
# Got 106 games.
# User 626: aleatorio00
# Got 765 games.
# User 627: titanshahmat2003
# Got 66 games.
# User 628: onandonandonandon
# Got 0 games.
# User 629: littleplotkin
# Got 1211 games.
# Error parsing move Qexe5: invalid uci: 'Qexe5'
# User 630: ManuDavid2910
# Got 0 games.
# User 631: Battousai14
# Got 0 games.
# User 632: Saqochess
# Got 891 games.
# Error parsing move Kf7: expected uci string to be of length 4 or 5: 'Kf7'
# User 633: artistendo
# Got 1215 games.
# User 634: The_Gate_to_Hell
# Got 0 games.
# User 635: Danil_Mark
# Got 1 games.
# User 636: pavaobjazevic
# Got 1679 games.
# User 637: Soham0705
# Got 117 games.
# User 638: daubon
# Got 29 games.
# User 639: Tintirito
# Got 0 games.
# User 640: Victory_Biber
# Got 703 games.
# User 641: CVRaman
# Got 0 games.
# User 642: Zubrrr
# Got 320 games.
# User 643: nmiq
# Got 190 games.
# User 644: puzzle10001
# Got 0 games.
# User 645: MW1966
# Got 1318 games.
# User 646: OhanyanEminChess
# Got 395 games.
# User 647: ryadden17
# Got 33 games.
# User 648: LookAroundUs
# Got 1 games.
# User 649: Artem_3000
# Got 233 games.
# User 650: Heart_of_Fire_Cat
# Got 0 games.
# User 651: arturchix
# Got 6 games.
# User 652: Minoli
# Got 5 games.
# User 653: QuCaNi
# Got 54 games.
# User 654: Kacparov
# Got 0 games.
# User 655: Bengalboy001
# Got 6 games.
# User 656: AndreyGnidenko
# Got 0 games.
# User 657: TheCableBox
# Got 46 games.
# User 658: Hripach007
# Got 0 games.
# User 659: Normal_one
# Got 0 games.
# User 660: rehbwf
# Got 43 games.
# User 661: F1nal_Masquerade
# Got 1 games.
# User 662: tamojerry
# Got 4 games.
# User 663: forgiants
# Got 6 games.
# User 664: gravereaper
# Got 628 games.
# User 665: Agent_000
# Got 11 games.
# User 666: Entuzijasta
# Got 2451 games.
# User 667: try_to_improve
# Got 8 games.
# User 668: Max05
# Got 6 games.
# User 669: pultis12
# Got 0 games.
# User 670: ViejoTortuga
# Got 14 games.
# User 671: Shatkirti
# Got 0 games.
# User 672: FaustiOro
# Got 225 games.
# User 673: xiaochess
# Got 5 games.
# User 674: larso
# Got 107 games.
# User 675: NowIAmSerious
# Got 4 games.
# User 676: E4D4_P
# Got 0 games.
# User 677: david23232323
# Got 70 games.
# User 678: Pilot100
# Got 790 games.
# User 679: QuarterPawn
# Got 8 games.
# User 680: Phillip_Shabelnikov
# Got 4267 games.
# User 681: The_main_event003
# Got 0 games.
# User 682: CoolChessPlayer6
# Got 300 games.
# User 683: chessmount
# Got 414 games.
# User 684: condansator3
# Got 106 games.
# User 685: Fingolfin69
# Got 433 games.
# User 686: DrVelja
# Got 0 games.
# User 687: Coach_EmreDemirbas
# Got 0 games.
# User 688: Heydarova
# Got 1 games.
# User 689: uzkuzk
# Got 2662 games.
# Error parsing move exd5: invalid uci: 'exd5'
# User 690: dongmchess
# Got 350 games.
# User 691: matvey_zhestkiy
# Got 0 games.
# User 692: DezertEagleR
# Got 0 games.
# User 693: Babushka28
# Got 0 games.
# User 694: Mikhailov_Viacheslav
# Got 11 games.
# User 695: chessmem
# Got 12 games.
# User 696: AVS2000
# Got 9 games.
# User 697: satlan
# Got 2 games.
# User 698: snow152
# Got 436 games.
# Error parsing move d4: expected uci string to be of length 4 or 5: 'd4'
# Error parsing move d4: expected uci string to be of length 4 or 5: 'd4'
# User 699: Murat_Chess9
# Got 52 games.
# User 700: Scarakazu
# Got 0 games.
# User 701: Jiordani_Jovanovich
# Got 0 games.
# User 702: chessm3g1c
# Got 0 games.
# User 703: LeraD
# Got 2 games.
# User 704: winx_m
# Got 0 games.
# User 705: derdo2121
# Got 20 games.
# User 706: tygrv_shlype1
# Got 0 games.
# User 707: MikeGScarn
# Got 0 games.
# User 708: Safinchess
# Got 38 games.
# User 709: gefuehlter_FM
# Got 8 games.
# User 710: Hematom87
# Got 1291 games.
# User 711: BrightFalcon
# Got 0 games.
# User 712: CarlsenNepo21
# Got 4 games.
# Error parsing move c4: expected uci string to be of length 4 or 5: 'c4'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# Error parsing move Nc3: expected uci string to be of length 4 or 5: 'Nc3'
# User 713: StarDream2011
# Got 0 games.
# User 714: charleshuang20
# Got 618 games.
# Error parsing move Kh8: expected uci string to be of length 4 or 5: 'Kh8'
# Error parsing move Bxf3: invalid uci: 'Bxf3'
# Error parsing move Rg1: expected uci string to be of length 4 or 5: 'Rg1'
# Error parsing move Rad1: invalid uci: 'Rad1'
# Error parsing move Nd4: expected uci string to be of length 4 or 5: 'Nd4'
# Error parsing move Rad8: invalid uci: 'Rad8'
# Error parsing move c4: expected uci string to be of length 4 or 5: 'c4'
# Error parsing move exd4: invalid uci: 'exd4'
# Error parsing move Nxe4: invalid uci: 'Nxe4'
# Error parsing move cxd5: invalid uci: 'cxd5'
# Error parsing move Bxc4: invalid uci: 'Bxc4'
# User 715: happykid0000
# Got 18 games.
# User 716: Sattifay
# Got 0 games.
# User 717: Tatur
# Got 718 games.
# Error parsing move g6: expected uci string to be of length 4 or 5: 'g6'
# Error parsing move d4: expected uci string to be of length 4 or 5: 'd4'
# Error parsing move exd8=R+: expected uci string to be of length 4 or 5: 'exd8=R+'
# Error parsing move d5: expected uci string to be of length 4 or 5: 'd5'
# Error parsing move fxe6+: invalid uci: 'fxe6+'
# Error parsing move Kd2: expected uci string to be of length 4 or 5: 'Kd2'
# Error parsing move Kd2: expected uci string to be of length 4 or 5: 'Kd2'
# Error parsing move fxe3: invalid uci: 'fxe3'
# Error parsing move g8=B: invalid uci: 'g8=B'
# Error parsing move Kd7: expected uci string to be of length 4 or 5: 'Kd7'
# Error parsing move h7: expected uci string to be of length 4 or 5: 'h7'
# Error parsing move h7: expected uci string to be of length 4 or 5: 'h7'
# Error parsing move d4: expected uci string to be of length 4 or 5: 'd4'
# Error parsing move Qxh1: invalid uci: 'Qxh1'
# Error parsing move Qh3xg3: expected uci string to be of length 4 or 5: 'Qh3xg3'
# Error parsing move Rff1: invalid uci: 'Rff1'
# Error parsing move c5: expected uci string to be of length 4 or 5: 'c5'
# Error parsing move c5: expected uci string to be of length 4 or 5: 'c5'
# Error parsing move Kf2: expected uci string to be of length 4 or 5: 'Kf2'
# Error parsing move e4: expected uci string to be of length 4 or 5: 'e4'
# Error parsing move e4: expected uci string to be of length 4 or 5: 'e4'
# Error parsing move Qba4: invalid uci: 'Qba4'
# Error parsing move Qxb7: invalid uci: 'Qxb7'
# Error parsing move e4: expected uci string to be of length 4 or 5: 'e4'
# User 718: mr-a7aaaa17a7a
# Got 1 games.
# User 719: BudakSadboy1234
# Got 0 games.
# User 720: bamsebear9
# Got 67 games.
# User 721: myfavoriteday
# Got 0 games.
# User 722: buldog58
# Got 5 games.
# User 723: marci_chess
# Got 0 games.
# User 724: Nichega
# Got 53 games.
# User 725: cobysters
# Got 48 games.
# Error parsing move Ne7: expected uci string to be of length 4 or 5: 'Ne7'
# Error parsing move Rc2: expected uci string to be of length 4 or 5: 'Rc2'
# Error parsing move Nd5: expected uci string to be of length 4 or 5: 'Nd5'
# Error parsing move Be6: expected uci string to be of length 4 or 5: 'Be6'
# Error parsing move Kg3: expected uci string to be of length 4 or 5: 'Kg3'
# Error parsing move Kf3: expected uci string to be of length 4 or 5: 'Kf3'
# Error parsing move Na3+: invalid uci: 'Na3+'
# Error parsing move Kd4: expected uci string to be of length 4 or 5: 'Kd4'
# Error parsing move Ba5: expected uci string to be of length 4 or 5: 'Ba5'
# Error parsing move g6: expected uci string to be of length 4 or 5: 'g6'
# Error parsing move Ne1: expected uci string to be of length 4 or 5: 'Ne1'
# Error parsing move Rc1+: invalid uci: 'Rc1+'
# Error parsing move h5: expected uci string to be of length 4 or 5: 'h5'
# Error parsing move Rb7: expected uci string to be of length 4 or 5: 'Rb7'
# Error parsing move g4: expected uci string to be of length 4 or 5: 'g4'
# Error parsing move a4: expected uci string to be of length 4 or 5: 'a4'
# Error parsing move Ke4: expected uci string to be of length 4 or 5: 'Ke4'
# Error parsing move Re3: expected uci string to be of length 4 or 5: 'Re3'
# Error parsing move Qf5: expected uci string to be of length 4 or 5: 'Qf5'
# Error parsing move Ra3: expected uci string to be of length 4 or 5: 'Ra3'
# Error parsing move Rb7: expected uci string to be of length 4 or 5: 'Rb7'
# Error parsing move Qa6: expected uci string to be of length 4 or 5: 'Qa6'
# Error parsing move Rb4: expected uci string to be of length 4 or 5: 'Rb4'
# Error parsing move Bg6+: invalid uci: 'Bg6+'
# Error parsing move Kf7: expected uci string to be of length 4 or 5: 'Kf7'
# Error parsing move Kf8: expected uci string to be of length 4 or 5: 'Kf8'
# Error parsing move f6: expected uci string to be of length 4 or 5: 'f6'
# Error parsing move Kxf4: invalid uci: 'Kxf4'
# Error parsing move Kg3: expected uci string to be of length 4 or 5: 'Kg3'
# Error parsing move Rxh5: invalid uci: 'Rxh5'
# Error parsing move Kg1: expected uci string to be of length 4 or 5: 'Kg1'
# Error parsing move Rd4: expected uci string to be of length 4 or 5: 'Rd4'
# Error parsing move Bxf7+: invalid uci: 'Bxf7+'
# Error parsing move Rc5: expected uci string to be of length 4 or 5: 'Rc5'
# User 726: Firephoenix05
# Got 6 games.
# Error parsing move Qd2: expected uci string to be of length 4 or 5: 'Qd2'
# Error parsing move Qd2: expected uci string to be of length 4 or 5: 'Qd2'
# Error parsing move Bf5: expected uci string to be of length 4 or 5: 'Bf5'
# User 727: Bashirli
# Got 0 games.
# User 728: Super_BrainPower
# Got 406 games.
# Error parsing move Bg7: expected uci string to be of length 4 or 5: 'Bg7'
# User 729: EricRosen
# Got 564 games.
# User 730: BerserkChess79
# Got 0 games.
# User 731: OwnYulix
# Got 68 games.
# User 732: Vlad_Lazarev79
# Got 397 games.
# Error parsing move c6: expected uci string to be of length 4 or 5: 'c6'
# Error parsing move Ke2: expected uci string to be of length 4 or 5: 'Ke2'
# Error parsing move Kc4: expected uci string to be of length 4 or 5: 'Kc4'
# Error parsing move Rc8+: invalid uci: 'Rc8+'
# Error parsing move Rf2+: invalid uci: 'Rf2+'
# User 733: bananarepublic21
# Got 0 games.
# User 734: DmDonCh
# Got 1 games.
# User 735: Nadigraj
# Got 0 games.
# User 736: gogotaniye
# Got 279 games.
# User 737: FaithfulElf
# Got 394 games.
# User 738: Vahe_S
# Got 26 games.
# User 739: DrawDenied_Twitch
# Got 461 games.
# User 740: Trrak55
# Got 3661 games.
# User 741: Vadim0507001012
# Got 5607 games.
# User 742: strongchamp100
# Got 77 games.
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move e5: expected uci string to be of length 4 or 5: 'e5'
# Error parsing move e5: expected uci string to be of length 4 or 5: 'e5'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move e5: expected uci string to be of length 4 or 5: 'e5'
# Error parsing move e5: expected uci string to be of length 4 or 5: 'e5'
# Error parsing move c6: expected uci string to be of length 4 or 5: 'c6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move c6: expected uci string to be of length 4 or 5: 'c6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move c6: expected uci string to be of length 4 or 5: 'c6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move c6: expected uci string to be of length 4 or 5: 'c6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move c6: expected uci string to be of length 4 or 5: 'c6'
# Error parsing move c6: expected uci string to be of length 4 or 5: 'c6'
# Error parsing move c6: expected uci string to be of length 4 or 5: 'c6'
# Error parsing move c6: expected uci string to be of length 4 or 5: 'c6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move c6: expected uci string to be of length 4 or 5: 'c6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move c6: expected uci string to be of length 4 or 5: 'c6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move c6: expected uci string to be of length 4 or 5: 'c6'
# Error parsing move c6: expected uci string to be of length 4 or 5: 'c6'
# Error parsing move c6: expected uci string to be of length 4 or 5: 'c6'
# Error parsing move b6: expected uci string to be of length 4 or 5: 'b6'
# Error parsing move c6: expected uci string to be of length 4 or 5: 'c6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move c6: expected uci string to be of length 4 or 5: 'c6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# Error parsing move Nf6: expected uci string to be of length 4 or 5: 'Nf6'
# User 743: Aleks-lexa
# Got 1392 games.
# User 744: SipahiPower
# Got 39 games.
# User 745: Immorrtalll
# Got 0 games.
# User 746: theblitzchamp
# Got 0 games.
# User 747: World-best-ninja
# Got 64 games.
# User 748: Dead_Pixel371
# Got 0 games.
# User 749: ImiRammstein
# Got 0 games.
# User 750: lattykk
# Got 6 games.
# User 751: Bandhawk
# Got 0 games.
# User 752: TryingNewThings1
# Got 0 games.
# Total games: 164589

# %%
# Out:
# Fri Oct 25 17:34:33 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# ---------------------------
# Step 6: Create DataFrame
# ---------------------------
#after creating the DataFrame, drop games with unknown openings
df = pd.DataFrame(all_data)

df_cleaned = df[df['opening'] != 'Unknown: Unknown']
print(f"Dropped {df.shape[0] - df_cleaned.shape[0]} games with unknown openings.")
df_cleaned.to_csv('lichess_games_data.csv', index=False)
print("Exported cleaned data to CSV.")

print(df.head())  # show first rows
# Out:
# Dropped 1818 games with unknown openings.
# Exported cleaned data to CSV.
#     game_id      white  white_rating       black  black_rating  \
# 0  hN05at52    aapp_61        1678.0      zwenna        2442.0
# 1  ttu4bd63     zwenna        2437.0     Aidas08        2136.0
# 2  Qwoly8kd  Ugjgjgjvj        2058.0      zwenna        2434.0
# 3  eMJwQKDV     zwenna        2433.0  Narcisse29        1820.0
# 4  8AFBBfka     zwenna        2433.0  Bracho2013        1089.0
#
#                                              opening winner  moves  \
# 0                   Sicilian Defense: Bowdler Attack  black     54
# 1  Sicilian Defense: Najdorf Variation, Zagreb Va...  white     77
# 2  Italian Game: Two Knights Defense, Modern Bish...  black     44
# 3  French Defense: Tarrasch Variation, Pawn Cente...  white     21
# 4                          Ruy Lopez: Berlin Defense  white     57
#
#                            link
# 0  https://lichess.org/hN05at52
# 1  https://lichess.org/ttu4bd63
# 2  https://lichess.org/Qwoly8kd
# 3  https://lichess.org/eMJwQKDV
# 4  https://lichess.org/8AFBBfka

# %%
# ---------------------------
# Step 7: Export CSV
# ---------------------------

df.to_csv('lichess_games_data.csv', index=False)
print("Exported to CSV.")
# Out:
# Exported to CSV.

# %% [markdown]
# ### Data processing:

# %%
df = pd.read_csv("lichess_games_data.csv")
df.head(5)
print(len(df))
# Out:
# 164589

# %% [markdown]
# ## Created repository with 160k+ games.
